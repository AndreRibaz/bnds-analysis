# %% [markdown]
# ### Exploração dos dados Parquet
# Vamos ler os arquivos Parquet da camada Bronze e fazer consultas iniciais.

# %%
import duckdb
import pandas as pd

# %%
con = duckdb.connect()

# %%
base_path = '../data/lake/silver/'

# Ler um parquet
parquet_file = base_path + 'br_bndes_operacoes.parquet'
df = con.execute(f"SELECT * FROM '{parquet_file}' LIMIT 5").fetchdf()
df.head()
# Out:
#                              razao_social_cliente    cnpj_cliente  \
# 0    COPACOL-COOPERATIVA AGROINDUSTRIAL CONSOLATA  76093731000190
# 1                  LAR COOPERATIVA AGROINDUSTRIAL  77752293000198
# 2                  LAR COOPERATIVA AGROINDUSTRIAL  77752293000198
# 3  COCARI - COOPERATIVA AGROPECUARIA E INDUSTRIAL  78956968000183
# 4  COCARI - COOPERATIVA AGROPECUARIA E INDUSTRIAL  78956968000183
#
#                                    descricao_projeto sigla_uf nome_municipio  \
# 0  INVESTIMENTOS EM AMPLIACAO DA CAPACIDADE DE RE...       PR  SEM MUNICÍPIO
# 1  DIRETA - AMPLICACAO DE LINHA DE ABATE DE FRANG...       PR     MATELANDIA
# 2  DIRETA - AMPLICACAO DE LINHA DE ABATE DE FRANG...       MS  SEM MUNICÍPIO
# 3  SUPLEMENTACAO DE RECURSOS A IMPLANTACAO DE UM ...       PR     MANDAGUARI
# 4  SUPLEMENTACAO DE RECURSOS A IMPLANTACAO DE UM ...       PR     MANDAGUARI
#
#    id_municipio id_contrato data_contratacao  valor_contratado  \
# 0          <NA>    09203361       2009-06-30        35900000.0
# 1       4115606    09203571       2009-06-29        66998000.0
# 2          <NA>    09203581       2009-06-30        20897000.0
# 3       4114203    09204441       2009-06-30        37000000.0
# 4       4114203    09204451       2009-10-09        50000000.0
#
#    valor_desembolsado  ... cnpj_instituicao_financeira_credenciada  \
# 0          35900000.0  ...                          92816560000137
# 1          66998000.0  ...                                     NaN
# 2          20897000.0  ...                          92816560000137
# 3          37000000.0  ...                          92816560000137
# 4          50000000.0  ...                          92816560000137
#
#                      tipo_garantia  tipo_excepcionalidade  situacao_contrato  \
# 0  DEFINIDA PELO AGENTE FINANCEIRO                   None          LIQUIDADO
# 1                             REAL                   None          LIQUIDADO
# 2  DEFINIDA PELO AGENTE FINANCEIRO                   None          LIQUIDADO
# 3  DEFINIDA PELO AGENTE FINANCEIRO                   None          LIQUIDADO
# 4  DEFINIDA PELO AGENTE FINANCEIRO                   None          LIQUIDADO
#
#    secao_cnae divisao_cnae grupo_cnae classe_cnae subclasse_cnae  \
# 0           C           10        101       10121        1012101
# 1           C           10        101       10121        1012101
# 2           C           10        101       10121        1012101
# 3           C           10        101       10121        1012101
# 4           C           10        101       10121        1012101
#
#    data_apuracao
# 0     2026-06-04
# 1     2026-06-04
# 2     2026-06-04
# 3     2026-06-04
# 4     2026-06-04
#
# [5 rows x 39 columns]

# %%
# Mostrar colunas do parquet
schema = con.execute(f"DESCRIBE SELECT * FROM '{parquet_file}'").fetchdf()
schema
# Out:
#                                 column_name column_type null   key default  \
# 0                      razao_social_cliente     VARCHAR  YES  None    None
# 1                              cnpj_cliente     VARCHAR  YES  None    None
# 2                         descricao_projeto     VARCHAR  YES  None    None
# 3                                  sigla_uf     VARCHAR  YES  None    None
# 4                            nome_municipio     VARCHAR  YES  None    None
# 5                              id_municipio      BIGINT  YES  None    None
# 6                               id_contrato     VARCHAR  YES  None    None
# 7                          data_contratacao        DATE  YES  None    None
# 8                          valor_contratado      DOUBLE  YES  None    None
# 9                        valor_desembolsado      DOUBLE  YES  None    None
# 10                      tipo_fonte_recursos     VARCHAR  YES  None    None
# 11                         custo_financeiro     VARCHAR  YES  None    None
# 12                               taxa_juros      DOUBLE  YES  None    None
# 13                           prazo_carencia      BIGINT  YES  None    None
# 14                        prazo_amortizacao      BIGINT  YES  None    None
# 15                         modalidade_apoio     VARCHAR  YES  None    None
# 16                              forma_apoio     VARCHAR  YES  None    None
# 17                                  produto     VARCHAR  YES  None    None
# 18              tipo_instrumento_financeiro     VARCHAR  YES  None    None
# 19                       indicador_inovacao      BIGINT  YES  None    None
# 20                   area_operacional_bndes     VARCHAR  YES  None    None
# 21                         setor_cnae_bndes     VARCHAR  YES  None    None
# 22             subsetor_agrupado_cnae_bndes     VARCHAR  YES  None    None
# 23                      descricao_subclasse     VARCHAR  YES  None    None
# 24                              setor_bndes     VARCHAR  YES  None    None
# 25                           subsetor_bndes     VARCHAR  YES  None    None
# 26                            porte_cliente     VARCHAR  YES  None    None
# 27                         natureza_cliente     VARCHAR  YES  None    None
# 28  nome_instituicao_financeira_credenciada     VARCHAR  YES  None    None
# 29  cnpj_instituicao_financeira_credenciada     VARCHAR  YES  None    None
# 30                            tipo_garantia     VARCHAR  YES  None    None
# 31                    tipo_excepcionalidade     VARCHAR  YES  None    None
# 32                        situacao_contrato     VARCHAR  YES  None    None
# 33                               secao_cnae     VARCHAR  YES  None    None
# 34                             divisao_cnae     VARCHAR  YES  None    None
# 35                               grupo_cnae     VARCHAR  YES  None    None
# 36                              classe_cnae     VARCHAR  YES  None    None
# 37                           subclasse_cnae     VARCHAR  YES  None    None
# 38                            data_apuracao        DATE  YES  None    None
#
#    extra
# 0   None
# 1   None
# 2   None
# 3   None
# 4   None
# 5   None
# 6   None
# 7   None
# 8   None
# 9   None
# 10  None
# 11  None
# 12  None
# 13  None
# 14  None
# 15  None
# 16  None
# 17  None
# 18  None
# 19  None
# 20  None
# 21  None
# 22  None
# 23  None
# 24  None
# 25  None
# 26  None
# 27  None
# 28  None
# 29  None
# 30  None
# 31  None
# 32  None
# 33  None
# 34  None
# 35  None
# 36  None
# 37  None
# 38  None

# %%
# Consultas iniciais

# Quantidade de linhas
total_linhas = con.execute(f"SELECT COUNT(*) AS total_linhas FROM '{parquet_file}'").fetchdf()
total_linhas
# Out:
#    total_linhas
# 0         23483

# %% [markdown]
# ### Consulta Diretorios CNAE

# %%
base_path = '../lake/silver/'

# Ler um parquet
parquet_file = base_path + 'br_bd_diretorios_brasil_cnae_2.parquet'
df = con.execute(f"SELECT * FROM '{parquet_file}' LIMIT 5").fetchdf()
df.head()
# Out:
#   subclasse                                descricao_subclasse classe  \
# 0   9700500                                Serviços domésticos  97005
# 1   9900800  Organismos internacionais e outras instituiçõe...  99008
# 2   0111301                                   Cultivo de arroz  01113
# 3   0111399  Cultivo de outros cereais não especificados an...  01113
# 4   0111302                                   Cultivo de milho  01113
#
#                                     descricao_classe grupo  \
# 0                                Serviços domésticos   970
# 1  Organismos internacionais e outras instituiçõe...   990
# 2                                 Cultivo de cereais   011
# 3                                 Cultivo de cereais   011
# 4                                 Cultivo de cereais   011
#
#                                      descricao_grupo divisao  \
# 0                                Serviços domésticos      97
# 1  Organismos internacionais e outras instituiçõe...      99
# 2                   Produção de lavouras temporárias      01
# 3                   Produção de lavouras temporárias      01
# 4                   Produção de lavouras temporárias      01
#
#                                    descricao_divisao secao  \
# 0                                Serviços Domésticos     T
# 1  Organismos Internacionais E Outras Instituiçõe...     U
# 2      Agricultura, Pecuária E Serviços Relacionados     A
# 3      Agricultura, Pecuária E Serviços Relacionados     A
# 4      Agricultura, Pecuária E Serviços Relacionados     A
#
#                                      descricao_secao  indicador_cnae_2_0  \
# 0                                Serviços Domésticos                   1
# 1  Organismos Internacionais E Outras Instituiçõe...                   1
# 2  Agricultura, Pecuária, Produção Florestal, Pes...                   1
# 3  Agricultura, Pecuária, Produção Florestal, Pes...                   1
# 4  Agricultura, Pecuária, Produção Florestal, Pes...                   1
#
#    indicador_cnae_2_1  indicador_cnae_2_2  indicador_cnae_2_3
# 0                   1                   1                   1
# 1                   1                   1                   0
# 2                   1                   1                   1
# 3                   1                   1                   1
# 4                   1                   1                   1

# %% [markdown]
# ### Consulta Diretorios Municípios

# %%
base_path = '../lake/silver/'

# Ler um parquet
parquet_file = base_path + 'br_bd_diretorios_brasil_municipio.parquet'
df = con.execute(f"SELECT * FROM '{parquet_file}' LIMIT 5").fetchdf()
df.head()
# Out:
#    id_municipio  id_municipio_6  id_municipio_tse  id_municipio_rf  \
# 0       5101837          510183              <NA>             <NA>
# 1       1100809          110080               477              681
# 2       1100338          110033               434               47
# 3       1100205          110020                35                3
# 4       1101104          110110               493              683
#
#    id_municipio_bcb                    nome  capital_uf  id_comarca  \
# 0              <NA>  Boa Esperança do Norte        <NA>        <NA>
# 1             46961      Candeias do Jamari           0     1100205
# 2             44516             Nova Mamoré           0     1100106
# 3             30719             Porto Velho           1     1100205
# 4             46851         Itapuã do Oeste           0     1100205
#
#    id_regiao_saude nome_regiao_saude  ...  nome_mesorregiao  \
# 0             <NA>               NaN  ...               NaN
# 1            11004    Madeira-Mamoré  ...   Madeira-Guaporé
# 2            11004    Madeira-Mamoré  ...   Madeira-Guaporé
# 3            11004    Madeira-Mamoré  ...   Madeira-Guaporé
# 4            11004    Madeira-Mamoré  ...   Madeira-Guaporé
#
#   id_regiao_metropolitana            nome_regiao_metropolitana   ddd  id_uf  \
# 0                     NaN                                  NaN  <NA>     51
# 1                     101  Região Metropolitana de Porto Velho    69     11
# 2                     NaN                                  NaN    69     11
# 3                     101  Região Metropolitana de Porto Velho    69     11
# 4                     NaN                                  NaN    69     11
#
#   sigla_uf      nome_uf   nome_regiao amazonia_legal  \
# 0       MT  Mato Grosso  Centro-Oeste              1
# 1       RO     Rondônia         Norte              1
# 2       RO     Rondônia         Norte              1
# 3       RO     Rondônia         Norte              1
# 4       RO     Rondônia         Norte              1
#
#                                     centroide
# 0   POINT(-54.9417429754238 -13.463197935201)
# 1  POINT(-63.3254198532114 -8.88702392955617)
# 2  POINT(-64.6295025002404 -10.3822863210755)
# 3  POINT(-64.3041357999869 -9.15394033687075)
# 4   POINT(-63.044960463046 -9.17019402601564)
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Join com descrição da divisão CNAE
# Vamos unir a tabela de operações com o diretório de CNAE para trazer a descrição da divisão.

# %%
base_operacoes = '../lake/silver/br_bndes_operacoes.parquet'
base_cnae = '../lake/silver/br_bd_diretorios_brasil_cnae_2.parquet'
base_municipio = '../lake/silver/br_bd_diretorios_brasil_municipio.parquet'

query = f"""
SELECT op.*, cnae.descricao_divisao, mn.sigla_uf, mn.nome_regiao FROM '{base_operacoes}' AS op
LEFT JOIN '{base_cnae}' AS cnae
    ON op.divisao_cnae = cnae.divisao
LEFT JOIN '{base_municipio}' AS mn
    ON op.id_municipio = mn.id_municipio
LIMIT 10
"""

resultado = con.execute(query).fetchdf()
resultado.head()
# Out:
#                              razao_social_cliente    cnpj_cliente  \
# 0                  LAR COOPERATIVA AGROINDUSTRIAL  77752293000198
# 1  COCARI - COOPERATIVA AGROPECUARIA E INDUSTRIAL  78956968000183
# 2  COCARI - COOPERATIVA AGROPECUARIA E INDUSTRIAL  78956968000183
# 3    COPACOL-COOPERATIVA AGROINDUSTRIAL CONSOLATA  76093731000190
# 4    COPACOL-COOPERATIVA AGROINDUSTRIAL CONSOLATA  76093731000190
#
#                                    descricao_projeto sigla_uf nome_municipio  \
# 0  DIRETA - AMPLICACAO DE LINHA DE ABATE DE FRANG...       PR     MATELANDIA
# 1  SUPLEMENTACAO DE RECURSOS A IMPLANTACAO DE UM ...       PR     MANDAGUARI
# 2  SUPLEMENTACAO DE RECURSOS A IMPLANTACAO DE UM ...       PR     MANDAGUARI
# 3  OPERACAO MISTA DO BNDES E BRDE PARA IMPLANTACA...       PR     CAFELANDIA
# 4  OPERACAO MISTA DO BNDES E BRDE PARA IMPLANTACA...       PR     CAFELANDIA
#
#    id_municipio id_contrato data_contratacao  valor_contratado  \
# 0       4115606    09203571       2009-06-29        66998000.0
# 1       4114203    09204441       2009-06-30        37000000.0
# 2       4114203    09204451       2009-10-09        50000000.0
# 3       4103453    10205201       2010-06-28        15244000.0
# 4       4103453    10205201       2010-06-28        34548000.0
#
#    valor_desembolsado  ... situacao_contrato secao_cnae  divisao_cnae  \
# 0          66998000.0  ...         LIQUIDADO          C            10
# 1          37000000.0  ...         LIQUIDADO          C            10
# 2          50000000.0  ...         LIQUIDADO          C            10
# 3          15244000.0  ...         LIQUIDADO          C            10
# 4          34548000.0  ...         LIQUIDADO          C            10
#
#    grupo_cnae  classe_cnae subclasse_cnae data_apuracao  \
# 0         101        10121        1012101    2026-06-04
# 1         101        10121        1012101    2026-06-04
# 2         101        10121        1012101    2026-06-04
# 3         101        10121        1012101    2026-06-04
# 4         101        10121        1012101    2026-06-04
#
#                      descricao_divisao sigla_uf_1  nome_regiao
# 0  Fabricação De Produtos Alimentícios         PR          Sul
# 1  Fabricação De Produtos Alimentícios         PR          Sul
# 2  Fabricação De Produtos Alimentícios         PR          Sul
# 3  Fabricação De Produtos Alimentícios         PR          Sul
# 4  Fabricação De Produtos Alimentícios         PR          Sul
#
# [5 rows x 42 columns]
